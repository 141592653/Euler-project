# %%
n = 4000000

# %%
curFib = 2
prevFib = 1
res = 0
while(curFib < n) :
    res += curFib 
    buff = curFib
    curFib += prevFib
    prevFib = curFib + buff
    curFib += prevFib

# %%
res
# Out:
# 4613732
